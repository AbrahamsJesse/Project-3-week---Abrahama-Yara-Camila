# %%
import requests
from bs4 import BeautifulSoup

import pandas as pd

# %% [markdown]
# # The project

# %%
#####################################################################################

# %% [markdown]
# # FIRST WEBSITE - **FMOVIES**

# %%
#https://www.fmovies.hn/filter?type=movie&quality=all&release_year=2023&genre=14&country=all

# %%
import requests

headers = {"user-agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/118.0.0.0 Safari/537.36"}

r = requests.get("https://www.fmovies.hn/filter?type=movie&quality=all&release_year=2023&genre=14&country=all&page=1", headers = headers)
r.status_code
# Out:
# 200

# %%
soup=BeautifulSoup(r.content)
type(soup)
# Out:
# bs4.BeautifulSoup

# %% [markdown]
# **CUADRO**

# %%
page = soup.find_all("div", attrs = {"class":"flw-item"})
page
# Out:
# [<div class="flw-item">
#  <div class="film-poster">
#  <div class="pick film-poster-quality">HD</div>
#  <img alt="The Puppetman-hd" class="film-poster-img lazyload" data-src="https://img.fmovies.hn/xxrz/250x400/346/d1/fe/d1fef875b23ee78a1a1cad25919ade78/d1fef875b23ee78a1a1cad25919ade78.jpg" title="The Puppetman"/>
#  <a class="film-poster-ahref flw-item-tip" href="/movie/watch-the-puppetman-full-101491" title="The Puppetman"><i class="fa fa-play"></i></a>
#  </div>
#  <div class="film-detail">
#  <h2 class="film-name"><a href="/movie/watch-the-puppetman-full-101491" title="The Puppetman">The Puppetman</a>
#  </h2>
#  <div class="fd-infor">
#  <span class="fdi-item">2023</span>
#  <span class="dot"></span>
#  <span class="fdi-item fdi-duration">89m</span>
#  <span class="float-right fdi-type">Movie</span>
#  </div>
#  <div class="clearfix"></div>
#  </div>
#  <div class="clearfix"></div>
#  </div>,
#  <div class="flw-item">
#  <div class="film-poster">
#  <div class="pick film-poster-quality">HD</div>
#  <img alt="Five Nights at Freddy's-hd" class="film-poster-img lazyload" data-src="https://img.fmovies.hn/xxrz/250x400/346/04/cc/04ccdc0a9ef65eed4069718dc557b1c9/04ccdc0a9ef65eed4069718dc557b1c9.jpg" title="Five Nights at Freddy's"/>
#  <a class="film-poster-ahref flw-item-tip" href="/movie/watch-five-nights-at-freddys-full-41631" title="Five Nights at Freddy's"><i class="fa fa-play"></i></a>
#  </div>
#  <div class="film-detail">
#  <h2 class="film-name"><a href="/movie/watch-five-nights-at-freddys-full-41631" title="Five Nights at Freddy's">Five Nights at Freddy's</a>
#  </h2>
#  <div class="fd-infor">
#  <span class="fdi-item">2023</span>
#  <span class="dot"></span>
#  <span class="fdi-item fdi-duration">110m</span>
#  <span class="float-right fdi-type">Movie</span>
#  </div>
#  <div class="clearfix"></div>
#  </div>
#  <div class="clearfix"></div>
#  </div>,
#  <div class="flw-item">
#  <div class="film-poster">
#  <div class="pick film-poster-quality">CAM</div>
#  <img alt="Malibu Horror Story-hd" class="film-poster-img lazyload" data-src="https://img.fmovies.hn/xxrz/250x400/346/2d/c1/2dc18c4d30fbb0a169bd4b872a19e111/2dc18c4d30fbb0a169bd4b872a19e111.jpg" title="Malibu Horror Story"/>
#  <a class="film-poster-ahref flw-item-tip" href="/movie/watch-the-malibu-tapes-full-44808" title="Malibu Horror Story"><i class="fa fa-play"></i></a>
#  </div>
#  <div class="film-detail">
#  <h2 class="film-name"><a href="/movie/watch-the-malibu-tapes-full-44808" title="Malibu Horror Story">Malibu Horror Story</a>
#  </h2>
#  <div class="fd-infor">
#  <span class="fdi-item">2023</span>
#  <span class="dot"></span>
#  <span class="fdi-item fdi-duration">88m</span>
#  <span class="float-right fdi-type">Movie</span>
#  </div>
#  <div class="clearfix"></div>
#  </div>
#  <div class="clearfix"></div>
#  </div>,
#  <div class="flw-item">
#  <div class="film-poster">
#  <div class="pick film-poster-quality">HD</div>
#  <img alt="Disco Inferno-hd" class="film-poster-img lazyload" data-src="https://img.fmovies.hn/xxrz/250x400/346/0b/c5/0bc5fcbcb954da65821bedeca142a698/0bc5fcbcb954da65821bedeca142a698.jpg" title="Disco Inferno"/>
#  <a class="film-poster-ahref flw-item-tip" href="/movie/watch-disco-inferno-full-101767" title="Disco Inferno"><i class="fa fa-play"></i></a>
#  </div>
#  <div class="film-detail">
#  <h2 class="film-name"><a href="/movie/watch-disco-inferno-full-101767" title="Disco Inferno">Disco Inferno</a>
#  </h2>
#  <div class="fd-infor">
#  <span class="fdi-item">2023</span>
#  <span class="dot"></span>
#  <span class="fdi-item fdi-duration">19m</span>
#  <span class="float-right fdi-type">Movie</span>
#  </div>
#  <div class="clearfix"></div>
#  </div>
#  <div class="clearfix"></div>
#  </div>,
#  <div class="flw-item">
#  <div class="film-poster">
#  <div class="pick film-poster-quality">HD</div>
#  <img alt="Flashback-hd" class="film-poster-img lazyload" data-src="https://img.fmovies.hn/xxrz/250x400/346/29/23/2923aa901df4eee9daceb011af424166/2923aa901df4eee9daceb011af424166.jpg" title="Flashback"/>
#  <a class="film-poster-ahref flw-item-tip" href="/movie/watch-flashback-full-101770" title="Flashback"><i class="fa fa-play"></i></a>
#  </div>
#  <div class="film-detail">
#  <h2 class="film-name"><a href="/movie/watch-flashback-full-101770" title="Flashback">Flashback</a>
#  </h2>
#  <div class="fd-infor">
#  <span class="fdi-item">2023</span>
#  <span class="dot"></span>
#  <span class="fdi-item fdi-duration">16m</span>
#  <span class="float-right fdi-type">Movie</span>
#  </div>
#  <div class="clearfix"></div>
#  </div>
#  <div class="clearfix"></div>
#  </div>,
#  <div class="flw-item">
#  <div class="film-poster">
#  <div class="pick film-poster-quality">HDRip</div>
#  <img alt="Fog City-hd" class="film-poster-img lazyload" data-src="https://img.fmovies.hn/xxrz/250x400/346/17/1c/171c665ea74472ff4f3ab2c3078315f7/171c665ea74472ff4f3ab2c3078315f7.jpg" title="Fog City"/>
#  <a class="film-poster-ahref flw-item-tip" href="/movie/watch-fog-city-full-101773" title="Fog City"><i class="fa fa-play"></i></a>
#  </div>
#  <div class="film-detail">
#  <h2 class="film-name"><a href="/movie/watch-fog-city-full-101773" title="Fog City">Fog City</a>
#  </h2>
#  <div class="fd-infor">
#  <span class="fdi-item">2023</span>
#  <span class="dot"></span>
#  <span class="fdi-item fdi-duration">97m</span>
#  <span class="float-right fdi-type">Movie</span>
#  </div>
#  <div class="clearfix"></div>
#  </div>
#  <div class="clearfix"></div>
#  </div>,
#  <div class="flw-item">
#  <div class="film-poster">
#  <div class="pick film-poster-quality">HD</div>
#  <img alt="Three Blind Mice-hd" class="film-poster-img lazyload" data-src="https://img.fmovies.hn/xxrz/250x400/346/4c/48/4c4866236b10aab9f0ae1d5308d8cd3a/4c4866236b10aab9f0ae1d5308d8cd3a.jpg" title="Three Blind Mice"/>
#  <a class="film-poster-ahref flw-item-tip" href="/movie/watch-three-blind-mice-full-101761" rel='"nofollow"' title="Three Blind Mice"><i class="fa fa-play"></i></a>
#  </div>
#  <div class="film-detail">
#  <h2 class="film-name"><a href="/movie/watch-three-blind-mice-full-101761" rel='"nofollow"' title="Three Blind Mice">Three Blind Mice</a>
#  </h2>
#  <div class="fd-infor">
#  <span class="fdi-item">2023</span>
#  <span class="dot"></span>
#  <span class="fdi-item fdi-duration">82m</span>
#  <span class="float-right fdi-type">Movie</span>
#  </div>
#  <div class="clearfix"></div>
#  </div>
#  <div class="clearfix"></div>
#  </div>,
#  <div class="flw-item">
#  <div class="film-poster">
#  <div class="pick film-poster-quality">HD</div>
#  <img alt="Flakka Zombie Drug-hd" class="film-poster-img lazyload" data-src="https://img.fmovies.hn/xxrz/250x400/346/81/1a/811a2afb8c478804a58cdf34a0715360/811a2afb8c478804a58cdf34a0715360.jpg" title="Flakka Zombie Drug"/>
#  <a class="film-poster-ahref flw-item-tip" href="/movie/watch-flakka-zombie-drug-full-101869" title="Flakka Zombie Drug"><i class="fa fa-play"></i></a>
#  </div>
#  <div class="film-detail">
#  <h2 class="film-name"><a href="/movie/watch-flakka-zombie-drug-full-101869" title="Flakka Zombie Drug">Flakka Zombie Drug</a>
#  </h2>
#  <div class="fd-infor">
#  <span class="fdi-item">2023</span>
#  <span class="dot"></span>
#  <span class="fdi-item fdi-duration">86m</span>
#  <span class="float-right fdi-type">Movie</span>
#  </div>
#  <div class="clearfix"></div>
#  </div>
#  <div class="clearfix"></div>
#  </div>,
#  <div class="flw-item">
#  <div class="film-poster">
#  <div class="pick film-poster-quality">HD</div>
#  <img alt="Dear David-hd" class="film-poster-img lazyload" data-src="https://img.fmovies.hn/xxrz/250x400/346/7b/39/7b3991bad6c377facaab1243805983b2/7b3991bad6c377facaab1243805983b2.jpg" title="Dear David"/>
#  <a class="film-poster-ahref flw-item-tip" href="/movie/watch
a>
#  </h2>
#  <div class="fd-infor">
#  <span class="fdi-item">2023</span>
#  <span class="dot"></span>
#  <span class="fdi-item fdi-duration">93m</span>
#  <span class="float-right fdi-type">Movie</span>
#  </div>
#  <div class="clearfix"></div>
#  </div>
#  <div class="clearfix"></div>
#  </div>,
#  <div class="flw-item">
#  <div class="film-poster">
#  <div class="pick film-poster-quality">HD</div>
#  <img alt="Beneath Us All-hd" class="film-poster-img lazyload" data-src="https://img.fmovies.hn/xxrz/250x400/346/e8/08/e8089af5b8b6b325514bfb8824ad4347/e8089af5b8b6b325514bfb8824ad4347.jpg" title="Beneath Us All"/>
#  <a class="film-poster-ahref flw-item-tip" href="/movie/watch-beneath-us-all-full-100585" title="Beneath Us All"><i class="fa fa-play"></i></a>
#  </div>
#  <div class="film-detail">
#  <h2 class="film-name"><a href="/movie/watch-beneath-us-all-full-100585" title="Beneath Us All">Beneath Us All</a>
#  </h2>
#  <div class="fd-infor">
#  <span class="fdi-item">2023</span>
#  <span class="dot"></span>
#  <span class="fdi-item fdi-duration">91m</span>
#  <span class="float-right fdi-type">Movie</span>
#  </div>
#  <div class="clearfix"></div>
#  </div>
#  <div class="clearfix"></div>
#  </div>,
#  <div class="flw-item">
#  <div class="film-poster">
#  <div class="pick film-poster-quality">HDRip</div>
#  <img alt="The Jester-hd" class="film-poster-img lazyload" data-src="https://img.fmovies.hn/xxrz/250x400/346/5a/0a/5a0a5a3e6c608c13de37c3ca95f6363c/5a0a5a3e6c608c13de37c3ca95f6363c.jpg" title="The Jester"/>
#  <a class="film-poster-ahref flw-item-tip" href="/movie/watch-the-jester-full-101080" title="The Jester"><i class="fa fa-play"></i></a>
#  </div>
#  <div class="film-detail">
#  <h2 class="film-name"><a href="/movie/watch-the-jester-full-101080" title="The Jester">The Jester</a>
#  </h2>
#  <div class="fd-infor">
#  <span class="fdi-item">2023</span>
#  <span class="dot"></span>
#  <span class="fdi-item fdi-duration">90m</span>
#  <span class="float-right fdi-type">Movie</span>
#  </div>
#  <div class="clearfix"></div>
#  </div>
#  <div class="clearfix"></div>
#  </div>]

# %% [markdown]
# **Name**

# %%
page[0].find_all("h2", attrs = {"class":"film-name"})[0].get_text().strip()
# Out:
# 'The Puppetman'

# %% [markdown]
# **Year**

# %%
page[0].find_all("span", attrs = {"class":"fdi-item"})[0].get_text().strip()
# Out:
# '2023'

# %% [markdown]
# **Duration**

# %%
page[0].find_all("span", attrs = {"class":'fdi-item fdi-duration'})[0].get_text().strip()
# Out:
# '89m'

# %% [markdown]
# **Quality**

# %%
page[0].find_all("div", attrs = {"class":"pick film-poster-quality"})[0].get_text().strip()
# Out:
# 'HD'

# %%
film_dict = {}
film_index = 0

for item in page:
    name = item.find_all("h2", attrs = {"class":"film-name"})[0].get_text().strip()
    year = item.find_all("span", attrs = {"class":"fdi-item"})[0].get_text().strip() 
    duration =  item.find_all("span", attrs = {"class":"fdi-item fdi-duration"})[0].get_text().strip()
    quality = item.find_all("div", attrs = {"class":"pick film-poster-quality"})[0].get_text().strip()
    
    film_dict[film_index] = {"name":name,  
                            "year":year,
                             "duration": duration,
                            'quality': quality}

    film_index += 1
film_dict
# Out:
# {0: {'name': 'The Puppetman',
#   'year': '2023',
#   'duration': '89m',
#   'quality': 'HD'},
#  1: {'name': "Five Nights at Freddy's",
#   'year': '2023',
#   'duration': '110m',
#   'quality': 'HD'},
#  2: {'name': 'Malibu Horror Story',
#   'year': '2023',
#   'duration': '88m',
#   'quality': 'CAM'},
#  3: {'name': 'Disco Inferno',
#   'year': '2023',
#   'duration': '19m',
#   'quality': 'HD'},
#  4: {'name': 'Flashback', 'year': '2023', 'duration': '16m', 'quality': 'HD'},
#  5: {'name': 'Fog City',
#   'year': '2023',
#   'duration': '97m',
#   'quality': 'HDRip'},
#  6: {'name': 'Three Blind Mice',
#   'year': '2023',
#   'duration': '82m',
#   'quality': 'HD'},
#  7: {'name': 'Flakka Zombie Drug',
#   'year': '2023',
#   'duration': '86m',
#   'quality': 'HD'},
#  8: {'name': 'Dear David', 'year': '2023', 'duration': '95m', 'quality': 'HD'},
#  9: {'name': 'The Conference',
#   'year': '2023',
#   'duration': '98m',
#   'quality': 'HD'},
#  10: {'name': '15 Cameras',
#   'year': '2023',
#   'duration': '89m',
#   'quality': 'HD'},
#  11: {'name': 'Scary Tales: Dead Zone',
#   'year': '2023',
#   'duration': '83m',
#   'quality': 'HD'},
#  12: {'name': 'Herd', 'year': '2023', 'duration': '97m', 'quality': 'HD'},
#  13: {'name': 'The Bell Keeper',
#   'year': '2023',
#   'duration': '91m',
#   'quality': 'HD'},
#  14: {'name': 'Dark Harvest',
#   'year': '2023',
#   'duration': '95m',
#   'quality': 'HD'},
#  15: {'name': "Monster Inside: America's Most Extreme Haunted House",
#   'year': '2023',
#   'duration': '87m',
#   'quality': 'HD'},
#  16: {'name': 'Night of the Hunted',
#   'year': '2023',
#   'duration': '95m',
#   'quality': 'HD'},
#  17: {'name': 'The Mill', 'year': '2023', 'duration': '105m', 'quality': 'HD'},
#  18: {'name': 'Vindicta', 'year': '2023', 'duration': '89m', 'quality': 'HD'},
#  19: {'name': 'When Evil Lurks',
#   'year': '2023',
#   'duration': '100m',
#   'quality': 'HD'},
#  20: {'name': 'The Exorcist: Believer',
#   'year': '2023',
#   'duration': '111m',
#   'quality': 'HD'},
#  21: {'name': 'House of Dolls',
#   'year': '2023',
#   'duration': '80m',
#   'quality': 'HD'},
#  22: {'name': 'Fables for the Witching Hour',
#   'year': '2023',
#   'duration': '82m',
#   'quality': 'HD'},
#  23: {'name': 'Circle City Supernatural',
#   'year': '2023',
#   'duration': '98m',
#   'quality': 'HD'},
#  24: {'name': 'The Exorcists',
#   'year': '2023',
#   'duration': '88m',
#   'quality': 'HD'},
#  25: {'name': 'Totally Killer',
#   'year': '2023',
#   'duration': '106m',
#   'quality': 'HD'},
#  26: {'name': 'Saw X', 'year': '2023', 'duration': '118m', 'quality': 'HD'},
#  27: {'name': 'Pet Sematary: Bloodlines',
#   'year': '2023',
#   'duration': '87m',
#   'quality': 'HD'},
#  28: {'name': 'V/H/S/85', 'year': '2023', 'duration': '110m', 'quality': 'HD'},
#  29: {'name': 'No One Will Save You',
#   'year': '2023',
#   'duration': '93m',
#   'quality': 'HD'},
#  30: {'name': 'Beneath Us All',
#   'year': '2023',
#   'duration': '91m',
#   'quality': 'HD'},
#  31: {'name': 'The Jester',
#   'year': '2023',
#   'duration': '90m',
#   'quality': 'HDRip'}}

# %% [markdown]
# **The dataframe**

# %%
###now lets transform it into a dataframe
pd.DataFrame.from_dict (film_dict, orient="index")
# Out:
#                                                  name  year duration quality
# 0                                       The Puppetman  2023      89m      HD
# 1                             Five Nights at Freddy's  2023     110m      HD
# 2                                 Malibu Horror Story  2023      88m     CAM
# 3                                       Disco Inferno  2023      19m      HD
# 4                                           Flashback  2023      16m      HD
# 5                                            Fog City  2023      97m   HDRip
# 6                                    Three Blind Mice  2023      82m      HD
# 7                                  Flakka Zombie Drug  2023      86m      HD
# 8                                          Dear David  2023      95m      HD
# 9                                      The Conference  2023      98m      HD
# 10                                         15 Cameras  2023      89m      HD
# 11                             Scary Tales: Dead Zone  2023      83m      HD
# 12                                               Herd  2023      97m      HD
# 13                                    The Bell Keeper  2023      91m      HD
# 14                                       Dark Harvest  2023      95m      HD
# 15  Monster Inside: America's Most Extreme Haunted...  2023      87m      HD
# 16                                Night of the Hunted  2023      95m      HD
# 17                                           The Mill  2023     105m      HD
# 18                                           Vindicta  2023      89m      HD
# 19                                    When Evil Lurks  2023     100m      HD
# 20                             The Exorcist: Believer  2023     111m      HD
# 21                                     House of Dolls  2023      80m      HD
# 22                       Fables for the Witching Hour  2023      82m      HD
# 23                           Circle City Supernatural  2023      98m      HD
# 24                                      The Exorcists  2023      88m      HD
# 25                                     Totally Killer  2023     106m      HD
# 26                                              Saw X  2023     118m      HD
# 27                           Pet Sematary: Bloodlines  2023      87m      HD
# 28                                           V/H/S/85  2023     110m      HD
# 29                               No One Will Save You  2023      93m      HD
# 30                                     Beneath Us All  2023      91m      HD
# 31                                         The Jester  2023      90m   HDRip

# %% [markdown]
# # FUNCTION

# %% [markdown]
# # ITERATE PAGES - DATAFRAME

# %%
total = pd.DataFrame()
total
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from IPython.display import display

movie_genres = {"mystery" : "1",
                "crime": "2",
                "true crime" : "2",
                "animation" : "3",
                "cartoon" : "3",
                "cartoons" : "3",
                "drama" : "4",
                "western" : "6",
                "comedy" : "7",
                "tv movie" : "8",
                "family" : "9",
                "family friendly" : "9",
                "action" : "10",
                "documentary" : "11",
                "romance" : "12",
                "fantasy" : "13",
                "horror" : "14",
                "music" : "15",
                "musical" : "15",
                "thriller" : "16",
                "war" : "17",
                "war movie" : "17",
                "adventure" : "18",
                "history" : "19",
                "historical" : "19",
                "sci-fi" : "31",
                "science fiction" : "31",
                "fantasy" : "31",
                "biography" : "37",
                "biopic" : "37",
                "bio-pic" : "37"}

def genre_function ():
    

    
    def pick_genre(answer):
            while True:
                user_input = input("Please enter a genre: ").lower()
                if user_input in answer:
                    return answer[user_input]
                else:
                    print("Error. Please check your spelling or choose a different genre")
    genre = pick_genre(movie_genres)
    print(genre)
        
        
        
    n_pages = int(input("How many pages you want?"))
    
    
    
    
    year = int(input("Select year of release"))
    def year_func(answer):
        if answer >= 2019:
            return answer
        else:
            answer = str(answer)
            return "older-2019"
    year_func(year)


    df = pd.DataFrame()


    for i in range(1, n_pages + 1):

        url = f"https://www.fmovies.hn/filter?type=movie&quality=all&release_year={year}&genre={genre}&country=all&page={i}"
        headers = {
            "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/118.0.0.0 Safari/537.36"
        }

        r = requests.get(url, headers=headers)
        r.status_code
        soup = BeautifulSoup(r.content)
        page = soup.find_all("div", attrs={"class": "flw-item"})

        film_dict = {}
        film_index = 0

        for item in page:
            name = item.find_all("h2", attrs={"class": "film-name"})[0].get_text().strip()
            year = item.find_all("span", attrs={"class": "fdi-item"})[0].get_text().strip()
            #duration = item.find_all("span", attrs={"class": "fdi-item fdi-duration"})[0].get_text().strip()
            #quality = item.find_all("div", attrs={"class": "pick film-poster-quality"})[0].get_text().strip()

            film_dict[film_index] = {
                "name": name,
                "year": year,
                "duration": duration,
                'quality': quality
            }

            film_index += 1
            movies = pd.DataFrame.from_dict(film_dict, orient="index")
            df = pd.concat([df,movies])

            df.reset_index(drop=True, inplace=True)
        display(df)
        return df

# %% [markdown]
# # CHECKING THE ACTOR

# %%
def actor_function ():
    actor_name= input ('first name of the actor')
    actor_surname= input ('surname of the actor')
    complete_name= actor_name.lower() +'-'+actor_surname.lower()

    url = f"https://www.fmovies.hn/cast/{complete_name}"
    headers = {
            "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/118.0.0.0 Safari/537.36"
        }
    print(url)
    r = requests.get(url, headers=headers)
    r.status_code
    soup = BeautifulSoup(r.content)
    page = soup.find_all("div", attrs={"class": "flw-item"})

    film_dict = {}
    film_index = 0

    for item in page:
            name = item.find_all("h2", attrs={"class": "film-name"})[0].get_text().strip()
            year = item.find_all("span", attrs={"class": "fdi-item"})[0].get_text().strip()
            #duration = item.find_all("span", attrs={"class": "fdi-item fdi-duration"})[0].get_text().strip()
            #quality = item.find_all("div", attrs={"class": "pick film-poster-quality"})[0].get_text().strip()

            film_dict[film_index] = {
                "name": name,
                "year": year,
                "duration": duration,
                'quality': quality
            }

            film_index += 1
            actor = pd.DataFrame.from_dict(film_dict, orient="index")
            #df = pd.concat([df,movies])

    #df.reset_index(drop=True, inplace=True)
    display (actor)
    return actor

# %% [markdown]
# # FUNTION

# %%
def main():
    action = input('Do you want to search by genre or by actor? (Type "genre" or "actor"): ').lower()

    if action == 'genre':
        genre_function()
    elif action == 'actor':
        actor_function()
    else:
        print('Invalid input. Please enter "genre" or "actor".')

if __name__ == '__main__':
    main()
# Out:
# Do you want to search by genre or by actor? (Type "genre" or "actor"): actor
# first name of the actornatalie
# surname of the actordormer
# https://www.fmovies.hn/cast/natalie-dormer
#                                      name  year duration quality
# 0                             Pets United  2020      90m   HDRip
# 1          Penny Dreadful: City of Angels  SS 1      90m   HDRip
# 2     The Dark Crystal: Age of Resistance  SS 1      90m   HDRip
# 3            Modern/love in 7 short films  2019      90m   HDRip
# 4            The Professor and the Madman  2019      90m   HDRip
# 5                            Patient Zero  2018      90m   HDRip
# 6                             In Darkness  2018      90m   HDRip
# 7                  Picnic at Hanging Rock  SS 1      90m   HDRip
# 8                              The Forest  2016      90m   HDRip
# 9   The Hunger Games: Mockingjay - Part 2  2015      90m   HDRip
# 10                  The Scandalous Lady W  2015      90m   HDRip
# 11  The Hunger Games: Mockingjay - Part 1  2014      90m   HDRip
# 12                          The Riot Club  2014      90m   HDRip
# 13                          The Counselor  2013      90m   HDRip
# 14                                   Rush  2013      90m   HDRip
# 15                              The Fades  SS 1      90m   HDRip
# 16                                   W.E.  2011      90m   HDRip
# 17     Captain America: The First Avenger  2011      90m   HDRip
# 18                               Flawless  2007      90m   HDRip
# 19                               Casanova  2005      90m   HDRip
